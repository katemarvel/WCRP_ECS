# %%
# %matplotlib notebook
import scipy.stats as stata
import numpy as np
import matplotlib.pyplot as plt
nsamp=100

def sigma(sf,sl):
    test=[]
    for i in range(nsamp):
        F=np.random.normal(3.7,sf,size=100)
        L=np.random.normal(1.1,sl,size=100)
        test+=[np.var(F/L)]
    return np.average(np.array(test))

# %%
testf=[sigma(sf,0) for sf in np.linspace(0,1,.1)]
testl=[sigma(0,sl) for sl in np.linspace(0,1,.1)]
# Out:
# /Users/kmarvel/anaconda3/envs/cdat_plus/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   """Entry point for launching an IPython kernel.
# /Users/kmarvel/anaconda3/envs/cdat_plus/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
plt.plot(testf)
plt.plot(testl)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
testl[:10]
# Out:
# [1.9721522630525295e-31,
#  0.0987435948952066,
#  0.48897699300571895,
#  56777.35220421931,
#  588.8189496909525,
#  9075.502956143528,
#  41902.196837601456,
#  13476.514783487544,
#  207367.34055802223,
#  27658.790760950298]
